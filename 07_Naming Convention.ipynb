# %% [markdown]
# # CONTENT
# ## 1.Indentifier
# ## 2.Why should we following this?
# ## 3.Points follow for identifier
# ## 4. Python identifier table
# ## 5.Comments in Program
#
# ## 1.Indentifier:
# #### ->A name in python program is called indetifier.
# #### Ex- package name, module name,variable name,function name ,class name ,method name .
# #### -> Python creator made some suggestions to the programmers regarding how to write identifier in a program.
#
# ## 2.Why should we following this?
# #### Whilw writing the programif we follow the naming conventions then the written code is,
# #### . Easy to understand
# #### .Easy to read
# #### .Easy to debug
#
# ## 3.Points follow for identifiers in python
# #### We need to follow some points to define an identifier.
# ### P1:
# #### While writing an identifier we can use,
# #### -> Alphabets,either uppe4 case or lower case.
# #### ->Numbers from 0 to 9.
# #### ->Underscore symbols (_).
# #### We are using any other symbol then we will get syntax error.
# #### EX-Programm name:demo2.py
# #### student_id:101
# #### print (student_id)
# #### EX-

# %%
q=101
print(q)
# Out:
# 101

# %% [markdown]
# #### P2 :
# #### We can write an identifier with number but identifier shouldn't start with digit.
# #### EX-Syntax error
# #### P3 :
# #### Identifiere are case sensitive.Ex-Name error
# #### P4:
# #### We can't use keyword as identifiers.
# #### P5:
# #### Spaces are not allowed in between the identifier.
# #### Ex- student56,_student...
# #### Common error:
# #### Syntax errror
# ## 4. Python identifier table:
# #### This table w3e can understand while studying upcoming topics.
# ## 5.Comments in Program
# #### There are 2 types of comments-
# #### a.Single line comments(Ex-#)
# #### b.Multi line comments (Ex-'''x''',"""x""")
# #### Purpose of comments:
# #### ->Comments are useful to describe about the code in an easy way.
# #### ->Python ignores comments while running the program.
# #### a.Single line comments
# #### ->By using single line comments, we can comment only a single line.
# #### ->To comment single line comments,we need to use hash symbol(#).
# #### b.Multi line comments :
# #### ->By using it we can comment multi lines.
# #### ->to comment multi lines,we nedd to use triple double quotes symbol.
