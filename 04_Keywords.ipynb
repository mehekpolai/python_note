# %% [markdown]
# # CONTENT
# ## 1.What is a keyword in python
# ## 2.How many keyword in python
# ## 3.All keywords in simple table
#
# ## 1.What is a keyword in python ?
# #### The word which is reserved to do a specific purpose ,that  word is called as Keyword or reserved word .
#
# ## 2.How many keyword in python ?
# #### There are 35 keywords are available.
#
# ## 3.All keywords in simple table
# #### Flow Control -if,else,elif ,for,while,break ,continue,pass  |Module|Logical|Checking|Deleting|Built in constants|Exception Handling |Asychronous
# ####  Variable - Global, Non local
# #### Function/Method - def ,with ,lambda ,yield,return
# #### Object Oriented  -class
# #### Module -import,from,as
# #### Logical -and, or,not
# #### Checking -is,in
# #### Deleting -del
# #### Built in constants -True,False,None
# #### Exception Handling -try,except,finally,raise,assert
# #### Asychronous -async,await
#
# #### ->All keywords in python contain only alphabets.
# #### ->There are is lower case except keywords,
# ####    .True    .False   .None
