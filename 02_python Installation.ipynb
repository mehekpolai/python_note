# %% [markdown]
# ## 1.Checking Python software installed or not in PC/Lapton :
# #### ->We can check python software installed or not in the PC.
# #### ->Open command prompt in your PC.
# #### ->Type "py" command in command and enter then check it.
# #### ->If python is not installed then we will get response as about screen shot
#
# ## 2. Download := (Executable file = .exe)
# #### ->We can download python software fron official website, we ca find url in below.
# ####   (https://www.python.org/downloads/)
# ## 3.Important steps while installing software :
# #### ->Once python software downloaded then we can install by clicking he software.
# #### ->While installing we should check the checkbox of : Add python 3.11 to Path
