# %% [markdown]
# # CONTENT
# ## 1.Definition
# ## 2.Purpose of the variable
# ## 3.Properties of variable
# ## 4.Naming Convetion to a variable
# ## 5.Creating a variable
# ## 6.Creating multiple variable in a single line
# ## 7.Single value for multiple variable
# ## 8. Variable re-Initilization
#
# ## 1.Definition :
# #### It is a reserved  memory location to store values.
#
# ## 2.Purpose of the variable :
# #### ->The purpose is to represent the data.
# #### ->Data means a collection of facts.
# #### ->Facts can be,.Alphanumeric,.alphabets,.Symbol,.Number
#
# ## 3.Properties of variable :
# #### ->Every variable has its own properties.
# #### ->every variable can contains,
# #### .Name   ,.Time   ,.Value
# #### Ex-
# #### a=10
# #### print(a)
# #### a ---->name of variable
# #### 10 ---->value of variable
# #### Type ----> integer data type
#
# ## 4.Naming Convetion to a variable :
# #### -> Name should start with lowercase .
# #### ->If name having multiple words,then separating every word with underscore(_) symbol is  a good practice.
#
# ## 5.Creating a variable :
# #### We need to follow below syntax to create a variable.
# #### Syntax:
# #### name_of_the_variable_value
# #### EX-a.Create one variable
# ####    b.create 2 variable
# ####    c.Create 2 variable and print
# ####    d.create a variable with meaningful text.
#
# #### IMPNOTE :
# #### ->Python having dynamic data type nature.
# #### ->it means ,while creating variables we no need to provide the data type explicity in python.
# #### ->Regarding data type we will learn in data type chapter.
#
# ## 6.Creating multiple variable in a single line
# #### -> we can creating multiple vari8ables in single line.
# #### ->RULE- there should be same number on the left and right-hand sides.Otherwise we will get error.
#
# ## 7.Single value for multiple variable:
# #### ->We can assign a single value to multiple variables silutaneously.
# #### Ex-

# %%
a=b=c=3
print(a)
print(b)
print(c)
# Out:
# 3
# 3
# 3

# %% [markdown]
# ## 8. Variable re-Initilization
# #### ->Based on requirement we can re-initialize existing variable value.
# #### ->In variable re-initialization  old values will be replaced with new values.

# %%
# EX-
sal=7000
print("my salary is:",sal)
# Out:
# my salary is: 7000

# %%
#EX-
sal=5000
sal=7000
print("my salary is :",sal)
# Out:
# my salary is : 7000
