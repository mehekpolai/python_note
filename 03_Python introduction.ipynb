# %% [markdown]
# # CONTENT
# ## 1.What is Python
# ## 2.Python programming application
# ## 3.History of python
# ## 4.Why the name was python
# ## 5.Python Support
#
# ## 1.What is Python ?
# #### ->It is a general purpose and high-level programming language.
# #### ->General purpose means, curently all company are using python programming language to develop, test and deploy the software application .
# #### ->High level programming means, it's human readable language and easy to understand.
#
# ## 2.Python programming application :
# #### Types of application             | Purpose
# #### a.Desktop application            | An application needs to install on every machine to work with that application
# #### b.Web application                | an application follows client-server architectures
# #### c.Database application           | Which perform CURD(create,update,retrieve and delete) operation in database
# #### d.Bigdata application            | which can process the bigdata
# #### e.Machine learning               | which enable computer to learn automatically from the past data
#
# ## 3.History of python :
# #### ->Python was create by GUIDO VAN ROSSOM in the year 1991 .
# #### ->python in an oper source network means we can download freely from www.python.org website and customise the code as well.
#
# ## 4.Why the name was python ?
# #### ->A TV shiw monty pythons flying circus was very much popular fun show  in 1970.
# #### ->So. GUIDO like this show and give this name to his programmimng language .
#
# ## 5.Python Support :
# #### C --> Functional programming langauge
# #### Java -->OOp langauge
# #### Python -->Function programming language + OOP Language
