# %% [markdown]
# # CONTENT
# ## 1.Ways to write a python program
# ## 2.Python Program execution steps
# ## 3.Understanding 1st python program
#
#
# #### python ->Programming Language
# ####        ->We can create a program
# #### Program-> Group of instructions
# #### python program->what are all ways to write  a program ?
#
# ### 1.Ways to write a python program ?
# #### We can write the python programs in many ways likes,
# #### -> by using any notepad, notepad++,Edit plus,IDLE,Jupyter,Anaconda,VS Code,Spyder,atom,pycharm IDE e.t.c
# #### ->Initially the best practice is, using notepad to python program.
#
# ## 2.Python Program execution steps :
# #### write- Notepad
# #### Run -Command prompt
# #### ->We can save this program with .py or .python extension .
# #### Finally we will get output.
# #### PROGRAMS  -> FOLDER
# #### 1.write   ->notepad
# #### 2.save    ->demo.py
# #### 3.run     ->py demo.py
# #### 4.output  ->Hello Gd Evng
#
# ## 3.Understanding 1st python program :
# #### print("Hello World")
# #### =>"print" is a predefined function in python.
# #### =>Purpose of print to display the output.
# #### =>"Hello World" is the string in python.
