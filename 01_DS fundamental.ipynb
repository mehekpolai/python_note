# %% [markdown]
# #                                                   CONTENT
# ### 1.Data Introduction
# ### 2.What is Data
# ### 3.Information
# ### 4.Data Processing
# ### 5.Data Information E.g.
# ### 6.What is Datascience

# %% [markdown]
# ## 1. Data Introdution
# #### ->Currently we ar living in the data world .
# #### ->Everyone is communicating by using devices and social network,due to thhis huge amount of data is generating.
# #### ->All appication are generating data.
# #####    - E-commerce application
# #####    - Banking application
# #####    - Social Network
# ## 2.What is data?
# #### ->This is  a collection of facts.(Facts :Numbers,alphabets,alhanumeric,images,audios,videos & e.t.c.
# ## 3. Information:
# #### ->Data we may not understand clearly,the processed data is called imformation.
# ## 4.Data Processing:
# #### ->Conerting the raw data into meaningfull information.
# ####        DATA  ------> PROCESS ------> INFORMATION
# ## 5. Data & Information Example .
# #### -> Data: Hari, Student,56....
# #### ->Information: Name-Hari
# ####                Age-56
# ####                Profession-Student
# ## 6. What is DataScience ?
# ####  Def:1
# ####  DataScience is a combination of scientific methods, algorithms,to extract knowledge and insights from data.
# #### Def:2
# #### data Science is all about how we take data,
# #### ->Process data
# #### ->Understand the past and present conditions
# #### ->Predicting the future result
# #### ->Create new industries/product condition

# %% [markdown]
# ### 7.SCIENTIST:
# #### Scientist is a person who have specific knowledge on specific scenario.
# ### NATURE OF SCIENTIST:
# #### A scientist conduct more research to archieve the results.
# ### PROCESS BEHIND THE SCIENTIST
# #### In simple word a scientist is someone who,
# #### ->Systematically gathers information
# #### ->Doing research
# #### ->Getting Evidence
# #### ->Test the Evidence
# #### ->Gaining Knowledge
# #### ->Understanding the knowledge
# #### ->sharing knowledge
# ## 8.Big data:
# #### Extremely large data set is called Big data.    Ex:-84PB
# ## 9. Data measurement Table:
# ### Charts
# ####  Bit                   Single Binary digit
# ####  Byte                   8 Bits
# ####  kilo Byte              1024 Byte
# ####  Mega Byte              1024 kilo Byte
# ####  Giga Byte              1024 Mega Byte
# ####  Tera Byte              1024 Giga Byte
# ####  Peta Byte              1024 Tera Byte
# ####  Exa Byte               1024 Peta Byte
# ####  Zetta Byte             1024 Exa Byte
# ####  Yotta Byte             1024 Zetta Byte
# ####  ->From GB to greateron are called as Big Data.
# ## 10.Types of Big Data:
# #### There are mainly 3 types of Big data.
# #### a.Structured   b.Semi-Structured  c.Unstructured
# ### a.Structured :
# #### ->Structured data will be stored in table formats like rows and columns.
# #### ->It is very easy to understand.
# #### ->Ex: a table in database, Excel file,CVS file
# ### b.Semi-Structured :
# #### ->It may not in proper format,this type data having some properties/tags.
# ####   Ex :-log file,audio,video,e-mail...
# ## 11. V Speciality in Big Data :
# #### * VOLUME :
# #### ->Volume of the data means , size of the data.
# #### ->Based on size only w can measure all the data is in big data or not.
# #### * VARIETY :
# #### ->Variety of data means,the generatd data may existing in different format like,
# #### Structured ,Semi-Structured ,Unstructured
# #### * VELOCITY :
# #### ->Velocity on data means ,speed of the data generating and processing from the source point.
# #### Inshort :
# #### Volume = size
# #### Variety = type
# #### Velocity = Speed
# ## 12.Data analytics :
# #### ->All companies are analysing big data to improve business.
# #### ->From the result of analysis, companies used to reach customers to understand them clearly.
# ### every company's Target :
# #### ultimate target of any company is wanted to stand in best position and should be competitive with other companies.
# ### Different types :
# #### There are mainly four types of analytics :-
# #### a.Descriptive analytics   b.Diagnostic analytics  c.Predictive analytics d.Prescriptive analytics
# ### a.Descriptive analytics :
# #### -> It helps to understand like what is happening?
# #### ->It provide the situation what is happening situations.
# ####    Ex: Amazon offered one product then then how the customer buying that specific product.
# ### b.Diagnostic analytics :
# #### ->It helps to understand like why did it happens?
# #### ->It is used to do a deeper understanding about the data to find out  the cause of events and behaviours.
# ### c.Predictive analytics :
# #### ->It helps to understand like what will be happens in future?
# #### ->It is used to understand the  future expectation,trends and provide the information about what will be happens in future.
# ### d.Prescriptive analytics :
# #### ->It helps to understand like whatis the next best action?
# #### ->It is used to apply the best decision action for improvement.
